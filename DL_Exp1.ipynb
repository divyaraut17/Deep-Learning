# %% [markdown]
# <a href="https://colab.research.google.com/github/divyaraut17/Deep-Learning/blob/main/DL_Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# %%
x_train = np.random.rand(1000, 10)
y_train = np.random.randint(0,2, size=(1000, 1))

# %% [markdown]
# **Define Model**

# %%
def  create_model():
    model = Sequential([
        Dense(64, activation='relu', input_shape=(10,)),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    return model

# %% [markdown]
# **SGD Optimizer**

# %%
print("\n Trainning with SGD optimizer")
model = create_model()


sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(
    optimizer=sgd_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('SGD Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with SGD optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5028 - loss: 0.7086
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4976 - loss: 0.7009
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4925 - loss: 0.6958
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4904 - loss: 0.6956
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4937 - loss: 0.6943
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4926 - loss: 0.6931
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5037 - loss: 0.6929
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5243 - loss: 0.6916
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4947 - loss: 0.6945
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4922 - loss: 0.6958
# Final loss: 0.6937560439109802
# Final accuracy: 0.49900001287460327

# %% [markdown]
# **Momentum Optimizer(SGD + momentum)**

# %%
print("\n Trainning with Momentum optimizer")
model = create_model()


momentum_optimizer = tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.9
    )
model.compile(
    optimizer=momentum_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('Momentum Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with Momentum optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4834 - loss: 0.6973
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4997 - loss: 0.6932
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5035 - loss: 0.6930
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5411 - loss: 0.6890
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5390 - loss: 0.6900
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5426 - loss: 0.6904
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5278 - loss: 0.6905
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5543 - loss: 0.6884
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5722 - loss: 0.6876
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5602 - loss: 0.6870
# Final loss: 0.6880117058753967
# Final accuracy: 0.550000011920929

# %% [markdown]
# **Nesterov Accelerated Gradient(NAG)**

# %%
print("\n Trainning with NAG optimizer")
model = create_model()


nag_optimizer = tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.9,
    nesterov=True
    )
model.compile(
    optimizer=nag_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('NAG Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with NAG optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4931 - loss: 0.6978
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5261 - loss: 0.6912
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5045 - loss: 0.6928
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5370 - loss: 0.6877
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5121 - loss: 0.6888
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5360 - loss: 0.6877
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5572 - loss: 0.6862
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5274 - loss: 0.6897
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5464 - loss: 0.6865
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5382 - loss: 0.6875
# Final loss: 0.6868367195129395
# Final accuracy: 0.5370000004768372

# %% [markdown]
# **AdaGrade Optimizer**

# %%
print("\n Trainning with Adagrade optimizer")
model = create_model()


adagrade_optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.01)
model.compile(
    optimizer=adagrade_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('Adagrade Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with Adagrade optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4803 - loss: 0.6954
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4839 - loss: 0.6951
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4759 - loss: 0.6951
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5037 - loss: 0.6935
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4695 - loss: 0.6939
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4943 - loss: 0.6928
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4933 - loss: 0.6926
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5087 - loss: 0.6924
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5024 - loss: 0.6925
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5015 - loss: 0.6918
# Final loss: 0.692279040813446
# Final accuracy: 0.5070000290870667

# %% [markdown]
# **RMS Prop Optimizer**

# %%
print("\n Trainning with RMS prop optimizer")
model = create_model()


rms_optimizer = tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho = 0.9
    )
model.compile(
    optimizer=rms_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('RMS prop Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with RMS prop optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4708 - loss: 0.6962
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5084 - loss: 0.6942
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5354 - loss: 0.6910
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5196 - loss: 0.6926
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5446 - loss: 0.6892
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5273 - loss: 0.6901
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5378 - loss: 0.6870
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5337 - loss: 0.6858
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5216 - loss: 0.6886
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5564 - loss: 0.6850
# Final loss: 0.6855642795562744
# Final accuracy: 0.5590000152587891

# %% [markdown]
# **Adam Optimizer**

# %%
print("\n Trainning with Adam optimizer")
model = create_model()


adam_optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1 = 0.9,
    beta_2 = 0.999
    )
model.compile(
    optimizer=adam_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('Adam Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with Adam optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5210 - loss: 0.6924
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5453 - loss: 0.6897
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5619 - loss: 0.6863
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5847 - loss: 0.6856
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5644 - loss: 0.6860
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5684 - loss: 0.6837
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5684 - loss: 0.6826
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5765 - loss: 0.6828
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5993 - loss: 0.6766
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5784 - loss: 0.6768
# Final loss: 0.6783556938171387
# Final accuracy: 0.5680000185966492

# %% [markdown]
# **AdamW Optimizer**

# %%
print("\n Trainning with AdamW optimizer")
model = create_model()


adamw_optimizer = tf.keras.optimizers.AdamW(
    learning_rate=0.001,
    weight_decay=0.1,
    )
model.compile(
    optimizer=adamw_optimizer,
     loss='binary_crossentropy',
     metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,batch_size=32)

print("Final loss:",history.history['loss'][-1])
print("Final accuracy:",history.history['accuracy'][-1])

plt.figure()
plt.plot(history.history['loss'])
plt.title('Adamw Optimizer - Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
#  Trainning with AdamW optimizer
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5084 - loss: 0.6922
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5547 - loss: 0.6885
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5556 - loss: 0.6878
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5693 - loss: 0.6857
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5578 - loss: 0.6846
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5563 - loss: 0.6839
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5793 - loss: 0.6801
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.6799
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5877 - loss: 0.6751
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5529 - loss: 0.6808
# Final loss: 0.6776672005653381
# Final accuracy: 0.5730000138282776
